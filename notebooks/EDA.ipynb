# %%
import os

print(os.getcwd())
# Out:
# /home/user/Documents/Data-Job-Market-Intelligence-Platform/notebooks

# %%
import os

print(os.listdir("../data"))
# Out:
# ['original_jobs.csv', 'cleaned_jobs.csv']

# %%
import pandas as pd

df = pd.read_csv("../data/original_jobs.csv")
df.head()
# Out:
#    id            title    company           location  \
# 0   1     Data Analyst       Meta       New York, NY
# 1   2     Data Analyst       Meta  San Francisco, CA
# 2   3     Data Analyst       Meta    Los Angeles, CA
# 3   4     Data Analyst       Meta     Washington, DC
# 4   5  Data Analyst II  Pinterest        Chicago, IL
#
#                                                 link    source date_posted  \
# 0  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 1  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 2  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 3  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 4  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-16
#
#    work_type  employment_type  \
# 0        NaN              NaN
# 1        NaN              NaN
# 2        NaN              NaN
# 3        NaN              NaN
# 4        NaN              NaN
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'work_type', 'employment_type', 'description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   object
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 82.0+ KB

# %%
df.describe()
# Out:
#                 id  work_type  employment_type
# count  1048.000000        0.0              0.0
# mean   1314.083969        NaN              NaN
# std     772.822422        NaN              NaN
# min       1.000000        NaN              NaN
# 25%     616.750000        NaN              NaN
# 50%    1303.500000        NaN              NaN
# 75%    2033.250000        NaN              NaN
# max    2534.000000        NaN              NaN

# %%
df.shape
# Out:
# (1048, 10)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'title',
#  'company',
#  'location',
#  'link',
#  'source',
#  'date_posted',
#  'work_type',
#  'employment_type',
#  'description']

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# **** *******                           9
# Name: count, dtype: int64

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Meta        70
# Netflix     33
# Amazon      18
# Google      16
# ****        14
# Lensa        9
# TikTok       8
# AARATECH     8
# ********     8
# *****        7
# Name: count, dtype: int64

# %%
df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# Seattle, WA                        15
# London, England, United Kingdom    15
# London Area, United Kingdom        14
# Austin, TX                         13
# Gurugram, Haryana, India           13
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                    0
# title                 0
# company               2
# location             15
# link                  0
# source               89
# date_posted          23
# work_type          1048
# employment_type    1048
# description           4
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["date_posted"] = pd.to_datetime(
    df["date_posted"],
    errors="coerce"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048 entries, 0 to 1047
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1048 non-null   int64
#  1   title            1048 non-null   object
#  2   company          1046 non-null   object
#  3   location         1033 non-null   object
#  4   link             1048 non-null   object
#  5   source           959 non-null    object
#  6   date_posted      1025 non-null   datetime64[ns]
#  7   work_type        0 non-null      float64
#  8   employment_type  0 non-null      float64
#  9   description      1044 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 82.0+ KB

# %%
df["company"] = df["company"].fillna("Unknown")
df["location"] = df["location"].fillna("Unknown")
df["source"] = df["source"].fillna("Unknown")
df["description"] = df["description"].fillna("")

# %%
df
# Out:
#         id                                              title  \
# 0        1                                       Data Analyst
# 1        2                                       Data Analyst
# 2        3                                       Data Analyst
# 3        4                                       Data Analyst
# 4        5                                    Data Analyst II
# ...    ...                                                ...
# 1043  2521                 Senior GIS/Data Management Analyst
# 1044  2531  Data Science Senior Associate - Card Data & An...
# 1045  2532  Vice President Data Scientist Marketing Analyt...
# 1046  2533           Lead Data Scientist - Finance Technology
# 1047  2534                     Applied AI/ML - Vice President
#
#                       company             location  \
# 0                        Meta         New York, NY
# 1                        Meta    San Francisco, CA
# 2                        Meta      Los Angeles, CA
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# title           0
# company         0
# location        0
# link            0
# source          0
# date_posted    23
# description     0
# dtype: int64

# %%
df["employment_type"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df["employment_type"].unique()
# Out:
# array([nan])

# %%
df.drop(columns=["employment_type", "work_type"], inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description'],
#       dtype='object')

# %%
df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# **** *******                           9
# Name: count, dtype: int64

# %%
df["company"].value_counts().head(10)
# Out:
# company
# Meta        70
# Netflix     33
# Amazon      18
# Google      16
# ****        14
# Lensa        9
# AARATECH     8
# TikTok       8
# ********     8
# *****        7
# Name: count, dtype: int64

# %%
df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# London, England, United Kingdom    15
# Seattle, WA                        15
# Unknown                            15
# London Area, United Kingdom        14
# Gurugram, Haryana, India           13
# Name: count, dtype: int64

# %%
df[df["company"] == "****"].head()
# Out:
#        id                             title company  \
# 618  1610               ****** **** *******    ****
# 619  1611  **** *******, ****** ***********    ****
# 633  1643                    **** *********    ****
# 643  1669          **** ********, *********    ****
# 644  1670          **** ********, *********    ****
#
#                          location  \
# 618  ********** **-********* ****
# 619                ***** ****, **
# 633                  *** ****, **
# 643               *** *******, **
# 644                ***** ****, **
#
#                                                   link    source date_posted  \
# 618  https://www.linkedin.com/jobs/view/people-data...  LinkedIn  2025-05-29
# 619  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-05-30
# 633  https://www.linkedin.com/jobs/view/data-scient...  LinkedIn  2025-06-02
# 643  https://www.linkedin.com/jobs/view/data-engine...  LinkedIn  2025-05-31
# ...

# %%
masked_companies = df["company"].str.contains(r"\*", regex=True, na=False).sum()
masked_titles = df["title"].str.contains(r"\*", regex=True, na=False).sum()
masked_locations = df["location"].str.contains(r"\*", regex=True, na=False).sum()

print("Masked companies:", masked_companies)
print("Masked titles:", masked_titles)
print("Masked locations:", masked_locations)
# Out:
# Masked companies: 72
# Masked titles: 72
# Masked locations: 72

# %%
print("Oldest Job:", df["date_posted"].min())
print("Newest Job:", df["date_posted"].max())
# Out:
# Oldest Job: 2025-04-10 00:00:00
# Newest Job: 2025-06-11 00:00:00

# %%
analysis_df = df.copy()

# %%
analysis_df.head(10)
# Out:
#    id                                              title      company  \
# 0   1                                       Data Analyst         Meta
# 1   2                                       Data Analyst         Meta
# 2   3                                       Data Analyst         Meta
# 3   4                                       Data Analyst         Meta
# 4   5                                    Data Analyst II    Pinterest
# 5   6                                       Data Analyst      FanDuel
# 6   7  Data Analyst, Production Finance Operations & ...      Netflix
# 7   8                           Data Analyst - Marketing      FanDuel
# 8   9                                       Data Analyst  SBH Fashion
# 9  14                                    Data Analyst II    Pinterest
#
#             location                                               link  \
# 0       New York, NY  https://www.linkedin.com/jobs/view/data-analys...
# ...

# %%
analysis_df = analysis_df[
    ~analysis_df["company"].str.contains(r"\*", regex=True, na=False)
]

analysis_df = analysis_df[
    ~analysis_df["title"].str.contains(r"\*", regex=True, na=False)
]

analysis_df = analysis_df[
    ~analysis_df["location"].str.contains(r"\*", regex=True, na=False)
]

# %%
analysis_df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description'],
#       dtype='object')

# %%
duplicates_df = analysis_df[
    analysis_df.duplicated(
        subset=["title", "company", "location"],
        keep=False
    )
].sort_values(
    by=["company", "title", "location"]
)

duplicates_df.head(20)
# Out:
#         id                        title              company  \
# 90     142                 Data Analyst             AARATECH
# 380    897                 Data Analyst             AARATECH
# 293    656                Data Engineer             ASOS.com
# 599   1514                Data Engineer             ASOS.com
# 296    659  Data Engineer I, SCOT - AIM               Amazon
# 298    661  Data Engineer I, SCOT - AIM               Amazon
# 303    667  Data Engineer I, SCOT - AIM               Amazon
# 305    669  Data Engineer I, SCOT - AIM               Amazon
# 794   2042   ML Data Linguist, Alexa AI               Amazon
# 807   2055   ML Data Linguist, Alexa AI               Amazon
# 546   1455                Data Engineer            Atlassian
# 1024  2491                Data Engineer            Atlassian
# 894   2276       Cyber Security Analyst  Chenega Corporation
# 1041  2519       Cyber Security Analyst  Chenega Corporation
# ...

# %%
analysis_df = analysis_df.drop_duplicates(
    subset=["title", "company", "location"]
).reset_index(drop=True)

# %%
duplicates_df = analysis_df[
    analysis_df.duplicated(
        subset=["title", "company", "location"],
        keep=False
    )
].sort_values(
    by=["company", "title", "location"]
)

duplicates_df.head(20)
# Out:
# Empty DataFrame
# Columns: [id, title, company, location, link, source, date_posted, description]
# Index: []

# %%
analysis_df.to_csv("../data/cleaned_jobs.csv",index=False)

# %%
len(analysis_df)
# Out:
# 923

# %%
analysis_df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description'],
#       dtype='object')

# %%
analysis_df["company"].value_counts().head(10)
# Out:
# company
# Meta         70
# Netflix      33
# Amazon       18
# Google       16
# Lensa         9
# AARATECH      8
# TikTok        8
# Handshake     7
# Uplers        6
# FanDuel       6
# Name: count, dtype: int64

# %%
analysis_df["title"].value_counts().head(10)
# Out:
# title
# Data Analyst                         152
# Data Scientist                        75
# Data Engineer                         58
# Data Scientist, Product Analytics     29
# Machine Learning Engineer             21
# Data Engineer, Product Analytics      20
# Senior Data Engineer                  13
# Senior Data Analyst                   12
# Junior Data Scientist                 11
# AI/ML Engineer                         9
# Name: count, dtype: int64

# %%
analysis_df["location"].value_counts().head(10)
# Out:
# location
# United States                      73
# New York, NY                       65
# San Francisco, CA                  49
# Bengaluru, Karnataka, India        40
# Remote, US                         23
# Unknown                            15
# Seattle, WA                        15
# London, England, United Kingdom    15
# London Area, United Kingdom        14
# Austin, TX                         13
# Name: count, dtype: int64

# %%
analysis_df.iloc[0]
# Out:
# id                                                             1
# title                                               Data Analyst
# company                                                     Meta
# location                                            New York, NY
# link           https://www.linkedin.com/jobs/view/data-analys...
# source                                                  LinkedIn
# date_posted                                  2025-04-14 00:00:00
# description    The Social Measurement team is a growing team ...
# Name: 0, dtype: object

# %%
analysis_df.iloc[5]
# Out:
# id                                                             6
# title                                               Data Analyst
# company                                                  FanDuel
# location                                            New York, NY
# link           https://www.linkedin.com/jobs/view/data-analys...
# source                                                  LinkedIn
# date_posted                                  2025-04-11 00:00:00
# description    About Fanduel\n\nFanDuel Group is the premier ...
# Name: 5, dtype: object

# %%
analysis_df["company"].iloc[10]
# Out:
# 'Pinterest'

# %%
analysis_df["title"].iloc[20]
# Out:
# 'Analytics Associate'

# %%
analysis_df["description_clean"] = analysis_df["description"].str.lower()

# %%
analysis_df
# Out:
#        id                                              title  \
# 0       1                                       Data Analyst
# 1       2                                       Data Analyst
# 2       3                                       Data Analyst
# 3       4                                       Data Analyst
# 4       5                                    Data Analyst II
# ..    ...                                                ...
# 918  2521                 Senior GIS/Data Management Analyst
# 919  2531  Data Science Senior Associate - Card Data & An...
# 920  2532  Vice President Data Scientist Marketing Analyt...
# 921  2533           Lead Data Scientist - Finance Technology
# 922  2534                     Applied AI/ML - Vice President
#
#                      company             location  \
# 0                       Meta         New York, NY
# 1                       Meta    San Francisco, CA
# 2                       Meta      Los Angeles, CA
# ...

# %%
analysis_df["description_clean"].iloc[0]
# Out:
# "the social measurement team is a growing team with high-visibility within the communications organization that is being tasked with measuring the efficacy and impact of our social-first communications and marketing efforts. you'll play a unique role in shaping the way we approach reporting, define success, and leverage our own data to support the communications team. in this role, you will employ data mining techniques to evaluate the success and efficacy of our social-first communications and marketing strategies. this role is also focused on social listening, where you'll be responsible for analyzing social conversation around specific topic areas. the ideal candidate will possess not only the technical proficiency to devise analytical solutions, but also have experience with data-storytelling.\n\ndata analyst responsibilities:\n\n\nemploy natural language processing (nlp) and social listening analytical techniques to understand how people discuss specific topics.\ncreate data pip
# ...

# %%
analysis_df.shape
# Out:
# (923, 9)

# %%
skills = [
    "python",
    "sql",
    "excel",
    "power bi",
    "tableau",
    "aws",
    "azure",
    "google cloud",
    "pandas",
    "numpy",
    "scikit-learn",
    "tensorflow",
    "pytorch",
    "machine learning",
    "deep learning",
    "statistics",
    "spark",
    "hadoop",
    "docker",
    "kubernetes",
    "git",
    "linux"
]
all_skills = []
analysis_df["description_clean"] = analysis_df["description_clean"].fillna("")
for i in range(len(analysis_df)):
    current_job_skills = []
    description=analysis_df["description_clean"].iloc[i]
    for skill in skills:
        if skill in description:
            current_job_skills.append(skill)
    all_skills.append(current_job_skills)

# %%
all_skills
# Out:
# [['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'tableau', 'machine learning', 'statistics', 'git'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['python', 'sql'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['python', 'sql', 'excel', 'tableau', 'git'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['python', 'sql', 'aws', 'statistics'],
#  ['sql', 'machine learning', 'git'],
#  ['python', 'sql', 'excel', 'tableau', 'aws'],
#  ['sql', 'excel', 'power bi', 'tableau'],
#  ['sql', 'excel', 'statistics', 'git'],
#  ['python', 'sql', 'excel', 'machine learning', 'statistics', 'spark'],
#  ['excel', 'statistics'],
#  ['sql', 'power bi', 'statistics'],
#  ['sql', 'excel', 'tableau'],
#  ['python', 'excel', 'tableau', 'git'],
# ...

# %%
len(all_skills)
# Out:
# 923

# %%
analysis_df["extracted_skills"] = all_skills

# %%
len(analysis_df)
# Out:
# 923

# %%
#df["description_clean"].isna().sum()

# %%
analysis_df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description', 'description_clean', 'extracted_skills'],
#       dtype='object')

# %%
analysis_df.to_csv("../data/processed_jobs.csv",index=False)

# %%
analysis_df[["title", "extracted_skills"]].head(10)
# Out:
#                                                title  \
# 0                                       Data Analyst
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4                                    Data Analyst II
# 5                                       Data Analyst
# 6  Data Analyst, Production Finance Operations & ...
# 7                           Data Analyst - Marketing
# 8                                       Data Analyst
# 9                                    Data Analyst II
#
#                                     extracted_skills
# 0  [python, sql, tableau, machine learning, stati...
# 1  [python, sql, tableau, machine learning, stati...
# 2  [python, sql, tableau, machine learning, stati...
# 3  [python, sql, tableau, machine learning, stati...
# 4                     [python, sql, aws, statistics]
# 5                 [python, sql, excel, tableau, aws]
# ...

# %%
print(analysis_df["description_clean"].iloc[0][:300])
# Out:
# the social measurement team is a growing team with high-visibility within the communications organization that is being tasked with measuring the efficacy and impact of our social-first communications and marketing efforts. you'll play a unique role in shaping the way we approach reporting, define s

# %%
print(analysis_df["description_clean"].iloc[1][:300])
# Out:
# the social measurement team is a growing team with high-visibility within the communications organization that is being tasked with measuring the efficacy and impact of our social-first communications and marketing efforts. you'll play a unique role in shaping the way we approach reporting, define s

# %%
analysis_df[["title", "company", "description_clean"]].iloc[0:5]
# Out:
#              title    company  \
# 0     Data Analyst       Meta
# 1     Data Analyst       Meta
# 2     Data Analyst       Meta
# 3     Data Analyst       Meta
# 4  Data Analyst II  Pinterest
#
#                                    description_clean
# 0  the social measurement team is a growing team ...
# 1  the social measurement team is a growing team ...
# 2  the social measurement team is a growing team ...
# 3  the social measurement team is a growing team ...
# 4  about pinterest\n\nmillions of people around t...

# %%
analysis_df[["location", "date_posted"]].head(5)
# Out:
#             location date_posted
# 0       New York, NY  2025-04-14
# 1  San Francisco, CA  2025-04-14
# 2    Los Angeles, CA  2025-04-14
# 3     Washington, DC  2025-04-14
# 4        Chicago, IL  2025-04-16

# %%
analysis_df[["link"]].head(5)
# Out:
#                                                 link
# 0  https://www.linkedin.com/jobs/view/data-analys...
# 1  https://www.linkedin.com/jobs/view/data-analys...
# 2  https://www.linkedin.com/jobs/view/data-analys...
# 3  https://www.linkedin.com/jobs/view/data-analys...
# 4  https://www.linkedin.com/jobs/view/data-analys...

# %%
analysis_df.iloc[0]
# Out:
# id                                                                   1
# title                                                     Data Analyst
# company                                                           Meta
# location                                                  New York, NY
# link                 https://www.linkedin.com/jobs/view/data-analys...
# source                                                        LinkedIn
# date_posted                                        2025-04-14 00:00:00
# description          The Social Measurement team is a growing team ...
# description_clean    the social measurement team is a growing team ...
# extracted_skills     [python, sql, tableau, machine learning, stati...
# Name: 0, dtype: object

# %%
analysis_df.iloc[1]
# Out:
# id                                                                   2
# title                                                     Data Analyst
# company                                                           Meta
# location                                             San Francisco, CA
# link                 https://www.linkedin.com/jobs/view/data-analys...
# source                                                        LinkedIn
# date_posted                                        2025-04-14 00:00:00
# description          The Social Measurement team is a growing team ...
# description_clean    the social measurement team is a growing team ...
# extracted_skills     [python, sql, tableau, machine learning, stati...
# Name: 1, dtype: object

# %%
analysis_df[["company", "title", "extracted_skills"]].sample(10, random_state=42)
# Out:
#                                                company  \
# 199                                        Wealthfront
# 541                                              Chewy
# 174           Jex - Recruitment for scaling businesses
# 468                                             Airbnb
# 66   PT Indofood CBP Sukses Makmur Tbk - Noodle Div...
# 493                                            Aviture
# 956                                  FutureCare Health
# 599                                           ASOS.com
# 960                    Texas Health and Human Services
# 158                                             Google
#
#                                         title  \
# 199                 Data Scientist, Marketing
# 541                           Data Engineer I
# 174                 Machine Learning Engineer
# 468           Staff Data Scientist, Locations
# 66                               Data Analyst
# 493                 Machine Learning Engineer
# ...

# %%
import ast
import pandas as pd

analysis_df = pd.read_csv("../data/processed_jobs.csv")

analysis_df["extracted_skills"] = analysis_df["extracted_skills"].apply(ast.literal_eval)

analysis_df.head()
# Out:
#    id            title    company           location  \
# 0   1     Data Analyst       Meta       New York, NY
# 1   2     Data Analyst       Meta  San Francisco, CA
# 2   3     Data Analyst       Meta    Los Angeles, CA
# 3   4     Data Analyst       Meta     Washington, DC
# 4   5  Data Analyst II  Pinterest        Chicago, IL
#
#                                                 link    source date_posted  \
# 0  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 1  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 2  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 3  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-14
# 4  https://www.linkedin.com/jobs/view/data-analys...  LinkedIn  2025-04-16
#
#                                          description  \
# 0  The Social Measurement team is a growing team ...
# 1  The Social Measurement team is a growing team ...
# ...

# %%
duplicates_df = analysis_df[
    analysis_df.duplicated(
        subset=["title", "company", "location"],
        keep=False
    )
].sort_values(
    by=["company", "title", "location"]
)

duplicates_df.head(20)
# Out:
# Empty DataFrame
# Columns: [id, title, company, location, link, source, date_posted, description, description_clean, extracted_skills]
# Index: []

# %%
len(analysis_df)
# Out:
# 923

# %%
skill_count = {}

for skills in analysis_df["extracted_skills"]:
    for skill in skills:
        if skill in skill_count:
            skill_count[skill] += 1
        else:
            skill_count[skill] = 1

# %%
list(skill_count.items())[:10]
# Out:
# [('python', 610),
#  ('sql', 654),
#  ('tableau', 244),
#  ('machine learning', 317),
#  ('statistics', 271),
#  ('git', 306),
#  ('aws', 276),
#  ('excel', 446),
#  ('power bi', 188),
#  ('spark', 205)]

# %%
sorted_skills = sorted(
    skill_count.items(),
    key=lambda x: x[1],
    reverse=True
)

# %%
print(sorted_skills)
# Out:
# [('sql', 654), ('python', 610), ('excel', 446), ('machine learning', 317), ('git', 306), ('aws', 276), ('statistics', 271), ('tableau', 244), ('spark', 205), ('power bi', 188), ('azure', 141), ('pytorch', 67), ('tensorflow', 61), ('hadoop', 59), ('deep learning', 57), ('kubernetes', 51), ('pandas', 48), ('docker', 48), ('google cloud', 46), ('scikit-learn', 44), ('numpy', 34), ('linux', 20)]

# %%
skill_df = pd.DataFrame(
    sorted_skills,
    columns=["skill", "count"]
)

# %%
skill_df
# Out:
#                skill  count
# 0                sql    654
# 1             python    610
# 2              excel    446
# 3   machine learning    317
# 4                git    306
# 5                aws    276
# 6         statistics    271
# 7            tableau    244
# 8              spark    205
# 9           power bi    188
# 10             azure    141
# 11           pytorch     67
# 12        tensorflow     61
# 13            hadoop     59
# 14     deep learning     57
# 15        kubernetes     51
# 16            pandas     48
# 17            docker     48
# 18      google cloud     46
# 19      scikit-learn     44
# 20             numpy     34
# 21             linux     20

# %%
top10 = skill_df.head(10)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select Top 10 skills
top10 = skill_df.head(10)

# Create figure
plt.figure(figsize=(10,6))

# Create horizontal bar chart
ax = sns.barplot(
    data=top10,
    x="count",
    y="skill",
    color="steelblue"
)

# Add title and labels
plt.title("Top 10 Most Demanded Skills", fontsize=16, fontweight="bold")
plt.xlabel("Number of Job Postings", fontsize=12)
plt.ylabel("Skill", fontsize=12)

# Add value labels at the end of each bar
for container in ax.containers:
    ax.bar_label(container, fmt="%d", padding=5)

# Add grid on x-axis
plt.grid(axis="x", linestyle="--", alpha=0.5)

# Save the figure
plt.savefig("top10_skills.png", dpi=300, bbox_inches="tight")

# Adjust layout
plt.tight_layout()

# Display plot
plt.show()

# %%
def count_skills(dataframe):
    
    skill_count = {}

    for skills in dataframe["extracted_skills"]:
        for skill in skills:
            if skill in skill_count:
                skill_count[skill] += 1
            else:
                skill_count[skill] = 1

    return skill_count

# %%
def create_skill_dataframe(skill_count):

    sorted_skills = sorted(
        skill_count.items(),
        key=lambda x:x[1],
        reverse=True
    )

    return pd.DataFrame(
        sorted_skills,
        columns=["skill","count"]
    )

# %%
def classify_role(title):
    title = str(title).lower()

    # Fraud roles FIRST
    if "fraud" in title:
        return "Other"

    # AI / ML roles
    elif any(keyword in title for keyword in [
    "machine learning",
    "ml engineer",
    "ml software engineer",
    "ai engineer",
    "ai/ml",
    "artificial intelligence",
    "deep learning",
    "nlp",
    "ai automation",
    "ai researcher"
   ]):
        return "Other"

    # Data Engineer
    elif "data" in title and "engineer" in title:
        return "Data Engineer"

    # Data Scientist
    elif any(keyword in title for keyword in [
        "data scientist",
        "research scientist",
        "applied scientist",
        "decision scientist",
        "analyst - data science",
        "data science",
        "quantitative researcher",
        "cientista de dados"
    ]):
        return "Data Scientist"

    # Data Engineer
    elif any(keyword in title for keyword in [
        "data engineer",
        "analytics engineer",
        "etl",
        "data platform",
        "data warehouse",
        "data clean room",
        "data migration"
    ]):
        return "Data Engineer"

    # Data Analyst
    elif any(keyword in title for keyword in [
    "data analyst",
    "business analyst",
    "bi analyst",
    "analytics",
    "insight analyst",
    "data analytics",
    "data analysis",
    "reporting analyst",
    "product analytics",
    "analista de dados",
    "business intelligence",
    "data visualization",
    "data intern"
   ]):
        return "Data Analyst"
    else:
        return "Other"


analysis_df["Role"] = analysis_df["title"].apply(classify_role)

# %%
data_analyst_df = analysis_df[
    analysis_df["Role"] == "Data Analyst"
]

data_engineer_df = analysis_df[
    analysis_df["Role"] == "Data Engineer"
]

data_scientist_df = analysis_df[
    analysis_df["Role"] == "Data Scientist"
]

ai_ml_df = analysis_df[
    analysis_df["Role"] == "AI/ML Engineer"
]

# %%
data_analyst_df.head(20)
# Out:
#     id                                              title          company  \
# 0    1                                       Data Analyst             Meta
# 1    2                                       Data Analyst             Meta
# 2    3                                       Data Analyst             Meta
# 3    4                                       Data Analyst             Meta
# 4    5                                    Data Analyst II        Pinterest
# 5    6                                       Data Analyst          FanDuel
# 6    7  Data Analyst, Production Finance Operations & ...          Netflix
# 7    8                           Data Analyst - Marketing          FanDuel
# 8    9                                       Data Analyst      SBH Fashion
# 9   14                                    Data Analyst II        Pinterest
# 10  15                                    Data Analyst II        Pinterest
# ...

# %%
analyst_skill_count=count_skills(data_analyst_df)
scientist_skill_count=count_skills(data_scientist_df)
engineer_skill_count=count_skills(data_engineer_df)

# %%
analyst_df = create_skill_dataframe(
    analyst_skill_count
)

scientist_df = create_skill_dataframe(
    scientist_skill_count
)

engineer_df = create_skill_dataframe(
    engineer_skill_count
)

# %%
def plot_bar_chart(dataframe, x_column, y_column, title,top_n=None):
    if top_n is not None:
      dataframe = dataframe.nlargest(top_n, x_column)
    plt.figure(figsize=(10,6))

    ax = sns.barplot(
        data=dataframe,
        x=x_column,
        y=y_column,
        color="steelblue"
    )

    plt.title(title, fontsize=16, fontweight="bold")

    plt.xlabel(x_column.capitalize())
    plt.ylabel(y_column.capitalize())

    for container in ax.containers:
        ax.bar_label(container, padding=5)

    plt.grid(axis="x", linestyle="--", alpha=0.5)

    plt.xlim(0, dataframe[x_column].max() * 1.1)

    plt.tight_layout()

    plt.show()

# %%
plot_bar_chart(
    analyst_df,
    "count",
    "skill",
    "Top 10 Skills for Data Analyst",
    top_n=10
)
plot_bar_chart(
    scientist_df.nlargest(10, "count"),
    "count",
    "skill",
    "Top 10 Skills for Data Scientist",
    top_n=10
)
plot_bar_chart(
    engineer_df.nlargest(10, "count"),
    "count",
    "skill",
    "Top 10 Skills for Data Engineer",
    top_n=10
)

# %% [markdown]
# #Insights from Role-wise skill Analysis
#
# 1.Overall Job Market
#   * SQL and Python are the two most frequently requested skills across all data-related roles.
#    * Cloud platforms like AWS and Azure are increasingly common, showing the industry's move toward cloud-  based data solutions.
#   * Visualization tools such as Tableau and Power BI remain important, especially for analytical roles.
#
# 2.Data Analyst
# * SQL is the most demanded skill, indicating that querying and analyzing structured data is a core responsibility.
# * Excel remains highly relevant, reflecting its continued use in business reporting and analysis.
# * Tableau and Power BI emphasize the importance of communicating insights through dashboards.
# * Python appears frequently, showing that programming skills are becoming increasingly valuable for analysts.
#
# 3.Data Scientist
# * Python is the dominant skill, highlighting its role in data analysis and machine learning.
# * Machine Learning and Statistics are among the most requested skills, reflecting the predictive nature of the role.
# * SQL continues to be essential for accessing and preparing data.
# * Spark appears more frequently than in analyst roles, indicating the need to work with larger datasets.
#
# 4.Data Engineer
# * SQL and Python form the foundation of Data Engineering.
# * Spark, Hadoop, and Kubernetes indicate strong demand for big data and distributed computing technologies.
# * AWS and Azure highlight the importance of cloud platforms in modern data engineering workflows.
# * Compared with analysts and data scientists, infrastructure-related technologies are more prominent.
#
#   | Observation     | Finding                                                |
# | --------------- | ------------------------------------------------------ |
# | Common skills   | Python and SQL are important across all three roles.   |
# | Analyst focus   | Business intelligence, reporting, and visualization.   |
# | Scientist focus | Machine Learning, Statistics, and predictive modeling. |
# | Engineer focus  | Big Data, Cloud, and Data Infrastructure.              |

# %% [markdown]
# # Future Improvements
# * Expand the predefined skill list to include more technologies and frameworks.
# * Analyze skill demand by company and location.
# * Develop an interactive Streamlit dashboard for exploration.
# * Add trend analysis if time-based data becomes available.
# * Recommend learning paths based on the most demanded skills.

# %%
analysis_df["company"].str.fullmatch(r"\*+", na=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# Name: company, Length: 923, dtype: bool

# %%
company_counts = analysis_df["company"].value_counts()

# %%
company_df = company_counts.reset_index()

# %%
company_df.columns = ["company", "count"]

# %%
plot_bar_chart(
    company_df,
    "count",
    "company",
    "Top 10 Hiring Companies",
    top_n=10
)

# %% [markdown]
# #Company wise Analysis Insights
#
# * Meta has the highest number of job postings (70) in this dataset.
# * Netflix is the second highest recruiter with 33 job postings.
# * The number of job postings drops significantly after the top two companies.
# * Both well-known companies and smaller organizations are hiring for data-related roles.

# %%
location_counts = analysis_df["location"].value_counts()

# %%
location_df = location_counts.reset_index()
location_df.columns = ["location", "count"]

# %%
plot_bar_chart(
    location_df,
    "count",
    "location",
    "Top 10 Hiring Locations",
    top_n=10
)

# %% [markdown]
# #Location wise Analysis
# 📌 Insights
#
# 1. The United States has the highest number of job postings (73), making it the most common hiring location in this dataset.
#
# 2. New York and San Francisco are among the top hiring cities, showing that many data-related opportunities are concentrated in major business and technology hubs.
#
# 3. Bengaluru, India is one of the top hiring locations, highlighting its importance as a major center for data and technology jobs.
#
# 4. The presence of Remote, US in the top five indicates that companies also offer remote opportunities for data-related roles.

# %%
skill_categories = {
    "Programming": [
        "python", "r"
    ],

    "Database": [
        "sql"
    ],

    "Cloud": [
        "aws", "azure", "google cloud"
    ],

    "Business Intelligence & Visualization": [
        "excel", "tableau", "power bi"
    ],

    "Machine Learning": [
        "machine learning",
        "deep learning",
        "scikit-learn",
        "tensorflow",
        "pytorch"
    ],

    "Data Analysis": [
        "pandas",
        "numpy",
        "statistics"
    ],

    "Big Data": [
        "spark",
        "hadoop"
    ],

    "DevOps": [
        "docker",
        "kubernetes",
        "linux"
    ],

    "Version Control": [
        "git"
    ]
}

# %%
category_count = {}

for category, skills in skill_categories.items():
    category_count[category] = 0

    for skill in skills:
        if skill in skill_count:
            category_count[category] += skill_count[skill]

# %%
skill_count
# Out:
# {'python': 610,
#  'sql': 654,
#  'tableau': 244,
#  'machine learning': 317,
#  'statistics': 271,
#  'git': 306,
#  'aws': 276,
#  'excel': 446,
#  'power bi': 188,
#  'spark': 205,
#  'pandas': 48,
#  'numpy': 34,
#  'azure': 141,
#  'google cloud': 46,
#  'hadoop': 59,
#  'scikit-learn': 44,
#  'pytorch': 67,
#  'tensorflow': 61,
#  'deep learning': 57,
#  'docker': 48,
#  'kubernetes': 51,
#  'linux': 20}

# %%
category_count
# Out:
# {'Programming': 610,
#  'Database': 654,
#  'Cloud': 463,
#  'Business Intelligence & Visualization': 878,
#  'Machine Learning': 546,
#  'Data Analysis': 353,
#  'Big Data': 264,
#  'DevOps': 119,
#  'Version Control': 306}

# %%
category_df = pd.DataFrame(
    list(category_count.items()),
    columns=["category", "count"]
)
category_df = category_df.sort_values(
    by="count",
    ascending=False
)
plot_bar_chart(
    category_df,
    "count",
    "category",
    "Most In-Demand Skill Categories"
)

# %% [markdown]
# #Skill Category Analysis
# Insights
# * Visualization tools (Excel, Tableau, Power BI) are highly valued, showing that presenting and communicating data is an important part of many data-related roles.
#
# * Programming and SQL remain core technical skills, making them essential for anyone preparing for a data career.
#
#
# * Companies increasingly expect candidates to have knowledge of Cloud and Machine Learning technologies in addition to traditional data analysis skills.
#
# * Specialized skills like Big Data and DevOps are valuable but are required mainly for specific roles such as Data Engineers and ML Engineers.

# %%
analyst_df["role"] = "Data Analyst"
scientist_df["role"] = "Data Scientist"
engineer_df["role"]="Data Engineer"

# %%
comparison_df = pd.concat([
    analyst_df,
    scientist_df,
    engineer_df
], ignore_index=True)

# %%
comparison_df.head()
# Out:
#       skill  count          role
# 0       sql    265  Data Analyst
# 1     excel    196  Data Analyst
# 2    python    158  Data Analyst
# 3   tableau    154  Data Analyst
# 4  power bi    131  Data Analyst

# %%
analyst_top10 = analyst_df.head(10)
scientist_top10 = scientist_df.head(10)
engineer_top10 = engineer_df.head(10)

# %%
comparison_df = pd.concat(
    [analyst_top10, scientist_top10, engineer_top10],
    ignore_index=True
)

# %%
common_skills = [
    "sql",
    "python",
    "excel",
    "tableau",
    "power bi",
    "statistics",
    "machine learning",
    "git",
    "aws",
    "spark"
]
def get_skill_count(df, skill):
    filtered_df = df[df["skill"] == skill]

    if filtered_df.empty:
        return 0

    return filtered_df["count"].iloc[0]

# %%
comparison_data = []

for skill in common_skills:
    comparison_data.append({
        "skill": skill,
        "Data Analyst": get_skill_count(analyst_df, skill),
        "Data Scientist": get_skill_count(scientist_df, skill),
        "Data Engineer": get_skill_count(engineer_df, skill)
    })

# %%
comparison_df = pd.DataFrame(comparison_data)

# %%
comparison_df
# Out:
#               skill  Data Analyst  Data Scientist  Data Engineer
# 0               sql           265             146            184
# 1            python           158             179            180
# 2             excel           196              75             87
# 3           tableau           154              43             38
# 4          power bi           131              24             25
# 5        statistics           114             116             16
# 6  machine learning            43             140             69
# 7               git            87              74             93
# 8               aws            61              45            110
# 9             spark            23              43            108

# %%
comparison_df.columns
# Out:
# Index(['skill', 'Data Analyst', 'Data Scientist', 'Data Engineer'], dtype='object')

# %%
heatmap_df = comparison_df.set_index("skill")

# %%
type(heatmap_df)
heatmap_df.shape
heatmap_df.head()
# Out:
#           Data Analyst  Data Scientist  Data Engineer
# skill
# sql                265             146            184
# python             158             179            180
# excel              196              75             87
# tableau            154              43             38
# power bi           131              24             25

# %%
plt.figure(figsize=(10, 6))

sns.heatmap(
    heatmap_df,
    annot=True,
    fmt="d",
    cmap="YlGnBu",
    linewidths=0.5
)

plt.title("Role vs Common Skill Demand")
plt.xlabel("Role")
plt.ylabel("skill")

plt.tight_layout()
plt.show()

# %% [markdown]
# #Role vs Common skills Demand
#
# 1.Insight 1
#
# * SQL and Python are the two most consistently demanded skills across all three data roles, making them essential technologies for aspiring data professionals.
#
# 2.Insight 2
#
# * Data Analyst roles place greater emphasis on business intelligence tools such as Excel, Tableau, and Power BI.
#
# 3.Insight 3
#
# * Data Scientist roles require stronger Machine Learning knowledge compared to Data Analyst and Data Engineer roles.
#
# 4. Insight 4
#
# * Data Engineer positions demand more Cloud and Big Data technologies such as AWS and Spark, reflecting their focus on building scalable data pipelines.
#
# 5. Insight 5
#
# * Git is consistently required across all three roles, indicating that version control is a standard industry practice.

# %%
len(analysis_df)
# Out:
# 923

# %%
analysis_df["company"].nunique()
# Out:
# 600

# %%
analysis_df["location"].nunique()
# Out:
# 326

# %%
skill_count["sql"]
# Out:
# 654

# %%
skill_count["python"]
# Out:
# 610

# %%
role_df = analysis_df["Role"].value_counts().reset_index()
role_df.columns = ["Role", "Jobs"]

# %%
analysis_df[
    analysis_df["title"].str.contains("Fraud Data Scientist", case=False, na=False)
][["title", "Role"]]
# Out:
#                     title   Role
# 117  Fraud Data Scientist  Other

# %%
analysis_df = analysis_df.drop(
    analysis_df[
        analysis_df["title"] == "Fraud Data Scientist"
    ].index
)

# %%
analysis_df[
    analysis_df["title"].str.contains("Fraud Data Scientist", case=False, na=False)
][["title", "Role"]]
# Out:
# Empty DataFrame
# Columns: [title, Role]
# Index: []

# %%
analysis_df.columns
# Out:
# Index(['id', 'title', 'company', 'location', 'link', 'source', 'date_posted',
#        'description', 'description_clean', 'extracted_skills', 'Role'],
#       dtype='object')

# %%
analysis_df[
    analysis_df["title"].str.contains("Machine Learning", case=False, na=False)
][["title", "Role"]].head()
# Out:
#                                                  title   Role
# 122  Machine Learning Engineer (L5) - Content & Med...  Other
# 148        Machine Learning Engineer (Berlin, Germany)  Other
# 153  Junior Artificial Intelligence (AI) / Machine ...  Other
# 161                          Machine Learning Engineer  Other
# 164                          Machine Learning Engineer  Other

# %%
analysis_df[
    analysis_df["title"].str.contains("engineer", case=False, na=False)
][["title", "Role"]].head(20)
# Out:
#                                                  title           Role
# 122  Machine Learning Engineer (L5) - Content & Med...          Other
# 132                                     AI/ML Engineer          Other
# 148        Machine Learning Engineer (Berlin, Germany)          Other
# 153  Junior Artificial Intelligence (AI) / Machine ...          Other
# 161                          Machine Learning Engineer          Other
# 164                          Machine Learning Engineer          Other
# 168                          Machine Learning Engineer          Other
# 171                          Machine Learning Engineer          Other
# 179                          Machine Learning Engineer          Other
# 182                 Machine Learning Engineer (Junior)          Other
# 183                          Machine Learning Engineer          Other
# 185                          Machine Learning Engineer          Other
# ...

# %%
role_df.head()
# Out:
#              Role  Jobs
# 0    Data Analyst   332
# 1   Data Engineer   210
# 2  Data Scientist   204
# 3           Other   177

# %%
analysis_df["Role"].value_counts()
# Out:
# Role
# Data Analyst      332
# Data Engineer     210
# Data Scientist    204
# Other             176
# Name: count, dtype: int64

# %%
analysis_df[
    analysis_df["Role"] == "Other"
]["title"].sample(20)
# Out:
# 30                             Customer Insights Analyst
# 237            Software Engineer, AI Platform - New Grad
# 428                                       AI/ML Engineer
# 892                Senior Data Center Operations Analyst
# 759                       Sales Associate Target Optical
# 743           Machine Learning Engineer I (Underwriting)
# 772                                        Work with Us!
# 719                                      React Developer
# 555                      Software/AI Engineer (New Grad)
# 620                             Business Systems Analyst
# 525                         Systems Software Engineer L4
# 27                        Data Products Analyst, YouTube
# 845                            Machine Learning Engineer
# 888                                  Senior C# Developer
# 902         DevOps Engineer - $20K Sign-On Bonus - 23302
# 122    Machine Learning Engineer (L5) - Content & Med...
# ...

# %%
len(analysis_df)
# Out:
# 922

# %%
analysis_df.to_csv("../data/processed_jobs.csv")
